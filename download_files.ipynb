# %%
import requests
import os

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
#file names and tokens
data = {
    "Samoylov_2002-2011_wind_speed.tab": "1cY3zyu9DT0VDTUInB3jW9irBeYVtSYxc",
    "Samoylov_2002-2011_meteorology.tab": "1j0e3oyldyjPdWAPeP7pdh44VVTC7dunI"
}   
    
path = 'data'
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist: 
  # Create a new directory because it does not exist 
  os.makedirs(path)
  print("The new directory is created!")

#download data
for key in data:
    download_file_from_google_drive(data[key], path + '/' + key)

# %%
#file names and tokens
gis = {
    "catchment.qpj": "117WAbjtLx4udeoyzuWXv51W090rtaHf2",
    "catchment.shx": "16Vz9WBsJq0p3V5W2dKhiwFuv8zd5T95R",
    "catchment.prj": "1Xyn8yKnJbuwoAj5edi_HR4jzAeZz921m",
    "catchment.cpg": "1dzZkYDyFjJQmcbS-QEUmvM9WF164iB-R",
    "catchment.dbf": "1t5j7NQQL705hnm2sDnuvtDswcBNTGQWl",
    "catchment.shp": "1wGgvs6xTpWgXyYjuwqA8M8q0PW_ienyx",
    "samoylov_surface_classification.tif": "1wyRJFq3BqnYPeZR85ngGZECVJyjunNs8",
}

path = 'gis'
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist: 
  # Create a new directory because it does not exist 
  os.makedirs(path)
  print("The new directory is created!")

#download data
for key in gis:
    download_file_from_google_drive(gis[key], path + '/' + key)
